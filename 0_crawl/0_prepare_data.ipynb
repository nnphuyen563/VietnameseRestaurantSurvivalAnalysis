# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

root_path = '/content/drive/MyDrive/DFS/pu/thesis/the_new_one/data'
# !ls $root_path
# Out:
# df_absa.csv  hcmc_restaurant.csv  hn_restaurant.csv  restaurant_data_en.json  restaurant_link.csv

# %%
# read json to df
import json
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-4b16d96e24d8> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 hcmc_df = pd.read_csv(os.path.join(root_path, 'restaurant_data_en.csv'), skiprows=2)
#       4
#       5 hcmc_df
#
# ...

# %%
import pandas as pd

hcmc_df = pd.read_csv(os.path.join(root_path, 'hcmc_restaurant.csv'), skiprows=2)
hn_df = pd.read_csv(os.path.join(root_path, 'hn_restaurant.csv'), skiprows=2)

combine_df = pd.concat([hcmc_df, hn_df], axis=0)
combine_df = combine_df.rename(
    columns = {
        'Unnamed: 0': 'link'
    }
)
combine_df = combine_df['link']
combine_df = combine_df.dropna()
combine_df = combine_df.reset_index(drop=True)
combine_df
# Out:
# 0      https://www.google.com/maps/place/Pasteur+Stre...
# 1      https://www.google.com/maps/place/Nh%C3%A0+H%C...
# 2      https://www.google.com/maps/place/Lanura+Resta...
# 3      https://www.google.com/maps/place/Din+Ky+Resta...
# 4      https://www.google.com/maps/place/Zen+Chinese+...
#                              ...
# 236    https://www.google.com/maps/place/Noodle+%26+R...
# 237    https://www.google.com/maps/place/Mikado+Ramen...
# 238    https://www.google.com/maps/place/Joy+House+St...
# 239    https://www.google.com/maps/place/Daluva+-+Ita...
# 240    https://www.google.com/maps/place/Meat+King+BB...
# Name: link, Length: 241, dtype: object

# %%
combine_df.to_csv(os.path.join(root_path, 'restaurant_link.csv'), index=False)
